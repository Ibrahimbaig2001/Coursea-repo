# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibrahimbaig2001/Coursea-repo/blob/main/Cars_99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Importing the data

# %%
df = pd.read_csv('Automobile_data.csv')

# %% [markdown]
# Reading the top ten elements in the dataset

# %%
df.head(10)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2          NaN    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
# 6      6         audi        wagon       105.8   192.7         ohc
# 7      9          NaN        sedan       101.2   176.8         ohc
# 8     10          bmw        sedan         NaN   176.8         ohc
# 9     11          bmw        sedan         NaN   176.8         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# ...

# %% [markdown]
# Counting the number of companies present in the dataset company column

# %%
df['company'].value_counts() # Counting the number of car companies in the data set
# Out:
# company
# toyota           7
# bmw              5
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# mitsubishi       3
# porsche          3
# volkswagen       3
# alfa-romero      2
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %%
df.describe() # Statistical Summary
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   58.000000   59.000000   61.000000        61.000000
# mean   40.885246   98.301724  173.015254  107.852459        25.803279
# std    25.429706    6.798981   13.845313   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  162.200000   68.000000        19.000000
# 50%    39.000000   96.000000  171.200000  100.000000        25.000000
# 75%    61.000000  101.000000  177.050000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
df.dtypes # Knowing about the data types of different columns
# Out:
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %% [markdown]
# Knowing about the number of columns and rows present in the dataset

# %%
df.shape # Tells about the number of rows and columns present in the dataset
# Out:
# (61, 10)

# %%
# Data Selection
df['price'] # Selecting only the price column
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
df.columns # gives all the columns present in the dataset in the form of array
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           57 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        58 non-null     float64
#  4   length            59 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  60 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %% [markdown]
# Selecting the columns from specifing their location

# %%
df.loc[3] # Accecing the 3 column in the dataframe
# Out:
# index                     3
# company                audi
# body-style            sedan
# wheel-base             99.8
# length                176.6
# engine-type             ohc
# num-of-cylinders       four
# horsepower              102
# average-mileage          24
# price               13950.0
# Name: 3, dtype: object

# %%
df.loc[:8] # Accecning 8 rows in the dataframe
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2          NaN    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
# 6      6         audi        wagon       105.8   192.7         ohc
# 7      9          NaN        sedan       101.2   176.8         ohc
# 8     10          bmw        sedan         NaN   176.8         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# ...

# %%
df.tail() # Gives the last 5 elements in the dataframe
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81         NaN      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df.isnull().values.any() # Checking for null values in the dataset
# Out:
# True

# %%
df.isnull().sum() # Gives the count of NAN/Null values present in the dataset
# Out:
# index               0
# company             4
# body-style          0
# wheel-base          3
# length              2
# engine-type         0
# num-of-cylinders    1
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %% [markdown]
# Filling the null values present in the price column by the mean of that column

# %%
df['price'].fillna(df['price'].mean(),inplace=True)

# %% [markdown]
# Checking whether the price column has been updated or not

# %%
df.isnull().sum() # Previoisly the price column contained 3 null values, but after replacing the NAN values with mean we dont have any null values
# Out:
# index               0
# company             4
# body-style          0
# wheel-base          3
# length              2
# engine-type         0
# num-of-cylinders    1
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df['num-of-cylinders'].value_counts() # Counting the number of different types of cylinders present in the dataset
# Out:
# num-of-cylinders
# four      38
# six       11
# five       5
# eight      3
# three      1
# twelve     1
# two        1
# Name: count, dtype: int64

# %%
df['num-of-cylinders'].fillna(value = "six", inplace = True) # Filling the one null value with the num-of-cylinders as six
# Out:
# <ipython-input-23-4e989b86410c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['num-of-cylinders'].fillna(value = "six", inplace = True) # Filling the one null value with the num-of-cylinders as six

# %%
df.isnull().sum()
# Out:
# index               0
# company             4
# body-style          0
# wheel-base          3
# length              2
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df['length'].fillna(df['length'].mean(), inplace = True) # replacing the null values present in the length column with the mean of the column
# Out:
# <ipython-input-25-588a5981d422>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['length'].fillna(df['length'].mean(), inplace = True) # replacing the null values present in the length column with the mean of the column

# %%
df.isnull().sum()
# Out:
# index               0
# company             4
# body-style          0
# wheel-base          3
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df1 = df[['company', 'price']][df.price == df['price'].max()]
print(df1) # Assigning the car company with highest price to df1
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
dft =df.groupby('body-style') # grouping all the body-style present in the dataframe

# %%
dft

# %%
dtyot = dft.get_group('sedan') # Accessing all the columns where body-style is sedan

# %%
print(dtyot)
# Out:
#     index        company body-style  wheel-base      length engine-type  \
# 3       3           audi      sedan        99.8  176.600000         ohc
# 4       4           audi      sedan        99.4  176.600000         ohc
# 5       5           audi      sedan        99.8  177.300000         ohc
# 7       9            NaN      sedan       101.2  176.800000         ohc
# 8      10            bmw      sedan         NaN  176.800000         ohc
# 9      11            bmw      sedan         NaN  176.800000         ohc
# 10     13            bmw      sedan         NaN  189.000000         ohc
# 11     14            bmw      sedan       103.5  173.015254         ohc
# 12     15            bmw      sedan       110.0  197.000000         ohc
# 15     18      chevrolet      sedan        94.5  158.800000         ohc
# 19     28          honda      sedan        96.5  175.400000         ohc
# 20     29          honda      sedan        96.5  169.100000         ohc
# ...

# %%
sdf = df.sort_values(by = ['price'], ascending = False)

# %%
sdf.head()
# Out:
#     index        company   body-style  wheel-base      length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0  199.200000        ohcv
# 11     14            bmw        sedan       103.5  173.015254         ohc
# 34     46  mercedes-benz        sedan       120.9  208.100000        ohcv
# 46     62        porsche  convertible        89.5  168.900000        ohcf
# 12     15            bmw        sedan       110.0  197.000000         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# 11              six         182               16  41315.0
# 34            eight         184               14  40960.0
# 46              six         207               17  37028.0
# 12              six         182               15  36880.0

# %%
df.describe() # Performing statistical summary again after fixing some missing values
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   58.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.301724  173.015254  107.852459        25.803279
# std    25.429706    6.798981   13.612602   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  165.300000   68.000000        19.000000
# 50%    39.000000   96.000000  171.700000  100.000000        25.000000
# 75%    61.000000  101.000000  176.800000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#              price
# count     61.00000
# mean   15387.00000
# std    11033.62446
# min     5151.00000
# 25%     6849.00000
# 50%    12940.00000
# 75%    17450.00000
# max    45400.00000

# %% [markdown]
# Standard Deviation , 25%, 50% , 75% have been affected after handling the null values

# %%
import pandas as pd
import numpy as np

# Assuming 'df' is your DataFrame
# Select only numerical columns for correlation calculation
numerical_df = df.select_dtypes(include=np.number)

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                     index  wheel-base    length  horsepower  average-mileage  \
# index            1.000000    0.046964  0.015318   -0.093809         0.176037
# wheel-base       0.046964    1.000000  0.870966    0.455915        -0.538118
# length           0.015318    0.870966  1.000000    0.639075        -0.769146
# horsepower      -0.093809    0.455915  0.639075    1.000000        -0.808804
# average-mileage  0.176037   -0.538118 -0.769146   -0.808804         1.000000
# price           -0.195768    0.653888  0.715175    0.803195        -0.732467
#
#                     price
# index           -0.195768
# wheel-base       0.653888
# length           0.715175
# horsepower       0.803195
# average-mileage -0.732467
# price            1.000000

# %%
df.corr(numeric_only=True)
# Out:
#                     index  wheel-base    length  horsepower  average-mileage  \
# index            1.000000    0.046964  0.015318   -0.093809         0.176037
# wheel-base       0.046964    1.000000  0.870966    0.455915        -0.538118
# length           0.015318    0.870966  1.000000    0.639075        -0.769146
# horsepower      -0.093809    0.455915  0.639075    1.000000        -0.808804
# average-mileage  0.176037   -0.538118 -0.769146   -0.808804         1.000000
# price           -0.195768    0.653888  0.715175    0.803195        -0.732467
#
#                     price
# index           -0.195768
# wheel-base       0.653888
# length           0.715175
# horsepower       0.803195
# average-mileage -0.732467
# price            1.000000

# %%
pd.get_dummies(df["num-of-cylinders"])
# Out:
#     eight   five   four    six  three  twelve    two
# 0   False  False   True  False  False   False  False
# 1   False  False   True  False  False   False  False
# 2   False  False  False   True  False   False  False
# 3   False  False   True  False  False   False  False
# 4   False   True  False  False  False   False  False
# ..    ...    ...    ...    ...    ...     ...    ...
# 56  False  False   True  False  False   False  False
# 57  False  False   True  False  False   False  False
# 58  False  False   True  False  False   False  False
# 59  False  False   True  False  False   False  False
# 60  False  False   True  False  False   False  False
#
# [61 rows x 7 columns]

# %%
df['company'].fillna(value = 'audi', inplace = True)
df["wheel-base"].fillna(df["wheel-base"].mean(),inplace = True)
# Out:
# <ipython-input-38-05ee81026b46>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['company'].fillna(value = 'audi', inplace = True)
# <ipython-input-38-05ee81026b46>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %% [markdown]
# There are no null values present in the dataset. Now we can proceed with feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
col = ["body-style","engine-type","company","num-of-cylinders"]
df[col] = df[col].apply(le.fit_transform) # performing label encoding on the mentioned columns to convert them from characters to numbers

# %%
df.head() # Our dataset only has numeric data
# Out:
#    index  company  body-style  wheel-base  length  engine-type  \
# 0      0        0           0        88.6   168.8            0
# 1      1        0           0        88.6   168.8            0
# 2      2        1           2        94.5   171.2            5
# 3      3        1           3        99.8   176.6            3
# 4      4        1           3        99.4   176.6            3
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0                 2         111               21  13495.0
# 1                 2         111               21  16500.0
# 2                 3         154               19  16500.0
# 3                 2         102               24  13950.0
# 4                 1         115               18  17450.0

# %%
df.dtypes
# Out:
# index                 int64
# company               int64
# body-style            int64
# wheel-base          float64
# length              float64
# engine-type           int64
# num-of-cylinders      int64
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %% [markdown]
# As we can see all our columns are of numeric type

# %%
le.fit_transform(["First","Second","Excellent"])
# Out:
# array([1, 2, 0])

# %%
from sklearn import preprocessing

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pdf = pca.fit_transform(df)

# %%
pdf
# Out:
# array([[-1.89195799e+03,  1.72206981e+00, -4.44364753e+01,
#         -6.11144557e-01, -6.46502893e+00, -3.84432444e+00,
#          5.54060676e-02, -3.12531818e+00, -3.92983578e-01,
#         -1.07426925e+00],
#        [ 1.11301661e+03, -9.43986716e+00, -3.98758151e+01,
#         -3.39980668e+00, -7.03051900e+00, -4.14475234e+00,
#         -1.90273160e-01, -3.23984758e+00, -3.86992387e-01,
#         -9.11058438e-01],
#        [ 1.11318915e+03,  3.27781600e+01, -4.73975753e+01,
#         -9.37269015e-01, -1.66533469e+00,  3.67318027e-01,
#          3.38718959e-01,  2.31124739e+00, -3.55830687e-01,
#         -3.65162541e-01],
#        [-1.43698867e+03, -8.04037993e+00, -3.74643760e+01,
#          9.57266224e+00,  9.92722884e-01,  3.39764011e-02,
#          1.22460562e-01,  4.11982109e-01, -9.68345290e-02,
#          6.94598014e-02],
#        [ 2.06303555e+03, -7.90176803e+00, -3.53474821e+01,
#          7.13295883e+00, -3.66153175e+00,  1.99826878e+00,
# ...

# %%
dat = pd.DataFrame(pdf)

# %%
dat.to_csv("p.csv")
